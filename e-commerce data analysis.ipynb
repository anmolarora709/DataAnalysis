# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Ecommerce Purchases.csv")

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 10        650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
num=df[df["Language"]=="en"]["Job"].value_counts().head()

# %%
num.plot.bar()

# %%
df.shape
# Out:
# (10000, 14)

# %%
df[df["Language"]=="en"]
# Out:
#                                                 Address    Lot AM or PM  \
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# 26          5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND       AM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 38    9671 Riley Drives Apt. 746\nPort Davidtown, TN...  15 vj       AM
# 44       907 Torres Spur Suite 083\nJuliefurt, NJ 99332  81 Ym       PM
# 54    1362 Woods Freeway Suite 659\nWeaverbury, NJ 9...  93 Zp       PM
# 66     59651 Turner Tunnel Apt. 702\nRuiztown, IA 59612  51 iB       AM
# 68    12962 Curtis Crescent\nWest Rickytown, OR 0859...  61 Lr       PM
# 77           1728 Ferguson Brook\nLake Deanna, MN 00857  26 qt       AM
# 94    0266 Orr Forge Apt. 617\nThomastown, MO 71752-...  89 KL       AM
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
d=df[df["AM or PM"]=="AM"]

# %%
number=d["Job"].value_counts().head(10)

# %%
number.plot.bar()

# %%
d["Purchase Price"].max()
# Out:
# 99.99

# %%
e=df[df["AM or PM"]=="AM"]

# %%
e.shape// exact same no of purchases during the day , and at night so we cannot say at which time of the day the site had maximum purchases
# Out:
# (4932, 14)

# %%
e["Purchase Price"].max()// max purchase throughout the day was for 99 dollars , and both of them were made at am and pm , we cannot say at what time of the day was the max purchase made
# Out:
# 99.99

# %%
d["Purchase Price"].mean()
# Out:
# 50.186510543390064

# %%
e["Purchase Price"].mean()
# Out:
# 50.186510543390064

# %%
d["Purchase Price"].sum()
# Out:
# 247519.87

# %%
e["Purchase Price"].sum()// our sale throughout the day was the same , 247519 ,at am and the same at pm so there is as such no time at which maximum sale is there
# Out:
# 247519.87

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 10        650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# ...

# %%
g=df[df["Job"]=="Drilling engineer"]

# %%
g
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 779               PSC 9956, Box 2820\nAPO AE 81969-8768  14 yG       PM
# 1104  32038 Adams Valley Suite 436\nNorth Kaylachest...  44 eL       AM
# 1303  98753 Smith Radial Suite 963\nSouth Jasmine, R...  45 cj       AM
# 1531                   PSC 7147, Box 5613\nAPO AE 35453  76 Cs       AM
# 2989  98274 Henderson Expressway Suite 475\nPort Hay...  32 Ls       PM
# 3558  01333 Nicholas Hill Suite 739\nEast Maria, DE ...  45 tj       AM
# 3753  96370 Shannon Isle Apt. 581\nRandallton, PA 62...  05 cD       PM
# 4840  031 Lang Plaza\nLake Matthewchester, NE 79519-...  13 DM       PM
# 4969   5865 Wendy Square\nNew Jacqueline, SD 40769-9181  02 JU       PM
# 4981                   PSC 9130, Box 5382\nAPO AP 58279  36 MU       PM
# ...

# %%
g["CC Provider"].value_counts()// most popular service provider among drilling engineers was VISA 16 digit
# Out:
# VISA 16 digit                  5
# Discover                       3
# Mastercard                     3
# Voyager                        3
# JCB 15 digit                   2
# Diners Club / Carte Blanche    2
# JCB 16 digit                   2
# American Express               1
# Name: CC Provider, dtype: int64

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 10        650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# ...

# %%
new.columns=['Popular CC Providers']

# %%
new
# Out:
#                              Popular CC Providers
# CC Provider
# American Express                              849
# Diners Club / Carte Blanche                   767
# Discover                                      817
# JCB 15 digit                                  868
# JCB 16 digit                                 1716
# Maestro                                       846
# Mastercard                                    816
# VISA 13 digit                                 777
# VISA 16 digit                                1715
# Voyager                                       829

# %%
purchases=df.groupby('Language')[["Purchase Price"]].count()
purchases.sort_values('Purchase Price' ,ascending=False).reset_index()
purchases.plot.bar()

# %%
purchases.columns=['data']

# %%
purchases
# Out:
#           data
# Language
# de        1155
# el        1137
# en        1098
# es        1095
# fr        1097
# it        1086
# pt        1118
# ru        1155
# zh        1059

# %%
df["Language"]
# Out:
# 0       el
# 1       fr
# 2       de
# 3       es
# 4       es
# 5       ru
# 6       de
# 7       pt
# 8       ru
# 9       zh
# 10      el
# 11      en
# 12      en
# 13      it
# 14      de
# 15      el
# 16      de
# 17      el
# 18      el
# 19      fr
# 20      de
# 21      it
# 22      en
# 23      ru
# 24      es
# 25      de
# 26      en
# 27      es
# 28      es
# 29      it
#         ..
# 9970    en
# 9971    de
# 9972    zh
# 9973    en
# 9974    el
# 9975    zh
# 9976    es
# 9977    fr
# 9978    de
# 9979    en
# 9980    fr
# 9981    pt
# 9982    it
# 9983    de
# 9984    el
# 9985    de
# 9986    it
# 9987    es
# 9988    de
# 9989    pt
# 9990    ru
# 9991    el
# 9992    de
# 9993    el
# 9994    zh
# 9995    it
# 9996    pt
# 9997    el
# 9998    es
# 9999    el
# Name: Language, Length: 10000, dtype: object

# %%
Y=df.get('Purchase Price')

# %%
X=df.get('Job')

# %%
plt.bar(X,Y,color='red',label='Gold')
plt.show()
